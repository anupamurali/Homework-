# %%
import csv
import numpy as np
import pylab as pl
import math
import pandas as pd

fname = 'train.csv'

train_df = pd.read_csv(fname,nrows=10000)
X = train_df.drop('smiles', 1).drop('gap', 1)
Y = train_df['gap']
train_matrix = X.as_matrix()
